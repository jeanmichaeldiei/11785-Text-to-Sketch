# %% [markdown]
# Take a look at the [repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) for more information

# %% [markdown]
# # Install

# %%
#!git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-450078e766ce> in <module>
#       1 import os
# ----> 2 os.chdir('pytorch-CycleGAN-and-pix2pix/')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'pytorch-CycleGAN-and-pix2pix/'

# %%
#!pip install -r requirements.txt #Uncomment if you need the install required packages

# %% [markdown]
# # Datasets
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_cyclegan_dataset.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images.
#
# -   Create a dataset folder under `/dataset` for your dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under your dataset's folder. Place any images you want to transform from a to b (cat2dog) in the `testA` folder, images you want to transform from b to a (dog2cat) in the `testB` folder, and do the same for the `trainA` and `trainB` folders.

# %%
#!bash ./datasets/download_cyclegan_dataset.sh horse2zebra #Uncomment if you want the install horse dataset

# %% [markdown]
# # Pretrained models
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_cyclegan_model.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
#!bash ./scripts/download_cyclegan_model.sh horse2zebra

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. I've found that a batch size of 16 fits onto 4 V100s and can finish training an epoch in ~90s.
#
# Once your model has trained, copy over the last checkpoint to a format that the testing model can automatically detect:
#
# Use `cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class A to class B and `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class B to class A.

# %%
# !python train.py --dataroot ./datasets/face2sketch --name face2sketch --model cycle_gan --preprocess 'resize_and_crop' --batch_size 2 --num_threads 0 --netG unet_256
# Out:
# ----------------- Options ---------------
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/face2sketch        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: cycle_gan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: face2sketch                   	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True
#                   no_flip: False
#                   no_html: False
#                      norm: instance
#               num_threads: 0                             	[default: 4]
#                 output_nc: 3
#                     phase: train
#                 pool_size: 50
#                preprocess: 'resize_and_crop'             	[default: resize_and_crop]
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# The number of training images = 202599
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 54.410 M
# [Network G_B] Total number of parameters : 54.410 M
# [Network D_A] Total number of parameters : 2.765 M
# [Network D_B] Total number of parameters : 2.765 M
# -----------------------------------------------
# Exception in user code:
# ------------------------------------------------------------
#
#
# Could not connect to Visdom server.
#  Trying to start a server....
# Command: E:\anaconda3\envs\scaleai2\python.exe -m visdom.server -p 8097 &>/dev/null &
# Setting up a new session...
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D8906AA88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /env/main (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D8906AA88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /env/main (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D8906AA88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# [WinError 10061] No connection could be made because the target machine actively refused it
# Visdom python client failed to establish socket to get messages from the server. This feature is optional and can be disabled by initializing Visdom with `use_incoming_socket=False`, which will prevent waiting for this request to timeout.
# E:\anaconda3\envs\scaleai2\lib\site-packages\torch\optim\lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D891FAF48>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D891FAF48>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D891FAF48>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D89219C88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D89219C88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D89219C88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D89219308>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D89219308>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D89219308>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D8921D388>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D8921D388>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D8921D388>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D8921DBC8>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D8921DBC8>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 711, in _send
#     data=json.dumps(msg),
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\visdom\__init__.py", line 677, in _handle_post
#     r = self.session.post(url, data=data)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 578, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=8097): Max retries exceeded with url: /events (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000028D8921DBC8>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 160, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 677, in urlopen
#     chunked=chunked,
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1262, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1308, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1257, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 1028, in _send_output
#     self.send(msg)
#   File "E:\anaconda3\envs\scaleai2\lib\http\client.py", line 968, in send
#     self.connect()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 187, in connect
#     conn = self._new_conn()
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connection.py", line 172, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000028D892402C8>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "E:\anaconda3\envs\scaleai2\lib\site-packages\urllib3\connectionpool.py", line 727, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
# create web directory ./checkpoints\face2sketch\web...
# learning rate 0.0002000 -> 0.0002000
# (epoch: 1, iters: 100, time: 0.156, data: 0.126) D_A: 0.354 G_A: 0.620 cycle_A: 3.428 idt_A: 0.521 D_B: 0.245 G_B: 0.450 cycle_B: 1.209 idt_B: 1.610
# Exception in user code:
# ------------------------------------------------------------
# (epoch: 1, iters: 200, time: 0.175, data: 0.054) D_A: 0.247 G_A: 0.564 cycle_A: 2.655 idt_A: 0.520 D_B: 0.191 G_B: 0.595 cycle_B: 1.143 idt_B: 0.854
# Exception in user code:
# ------------------------------------------------------------
# (epoch: 1, iters: 300, time: 0.160, data: 0.024) D_A: 0.160 G_A: 0.415 cycle_A: 1.866 idt_A: 0.334 D_B: 0.188 G_B: 0.480 cycle_B: 0.801 idt_B: 0.853
# Exception in user code:
# ------------------------------------------------------------
# Exception in user code:
# ------------------------------------------------------------
# Exception in user code:
# ------------------------------------------------------------
# (epoch: 1, iters: 400, time: 4.378, data: 0.045) D_A: 0.291 G_A: 0.952 cycle_A: 2.424 idt_A: 0.695 D_B: 0.179 G_B: 0.545 cycle_B: 1.624 idt_B: 0.694
# Exception in user code:
# ------------------------------------------------------------
# (epoch: 1, iters: 500, time: 0.164, data: 0.023) D_A: 0.121 G_A: 0.664 cycle_A: 1.495 idt_A: 0.552 D_B: 0.160 G_B: 0.277 cycle_B: 1.539 idt_B: 0.618
# Exception in user code:
# (epoch: 2, iters: 77700, time: 0.157, data: 0.030) D_A: 0.006 G_A: 1.158 cycle_A: 0.645 idt_A: 0.115 D_B: 0.053 G_B: 0.383 cycle_B: 0.515 idt_B: 0.095
# (epoch: 2, iters: 77800, time: 0.297, data: 0.027) D_A: 0.015 G_A: 0.676 cycle_A: 0.572 idt_A: 0.055 D_B: 0.032 G_B: 0.389 cycle_B: 0.401 idt_B: 0.087
# (epoch: 2, iters: 77900, time: 0.163, data: 0.036) D_A: 0.031 G_A: 1.019 cycle_A: 0.543 idt_A: 0.100 D_B: 0.124 G_B: 0.433 cycle_B: 0.401 idt_B: 0.104
# (epoch: 2, iters: 78000, time: 0.164, data: 0.035) D_A: 0.011 G_A: 0.792 cycle_A: 0.417 idt_A: 0.076 D_B: 0.129 G_B: 0.605 cycle_B: 0.417 idt_B: 0.062
# (epoch: 2, iters: 78100, time: 0.162, data: 0.038) D_A: 0.007 G_A: 0.589 cycle_A: 0.381 idt_A: 0.058 D_B: 0.170 G_B: 0.248 cycle_B: 0.353 idt_B: 0.053

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout`
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > The option --model test is used for generating results of CycleGAN only for one side. This option will automatically set --dataset_mode single, which only loads the images from one set. On the contrary, using --model cycle_gan requires loading and generating results in both directions, which is sometimes unnecessary. The results will be saved at ./results/. Use --results_dir {directory_path_to_save_result} to specify the results directory.
#
# > For your own experiments, you might want to specify --netG, --norm, --no_dropout to match the generator architecture of the trained model.

# %%
# !python test.py --dataroot ./datasets/face2sketch/trainA --name face2sketch --model test --no_dropout --netG unet_256 --num_test 202599
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/face2sketch/trainA 	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: face2sketch                   	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256                      	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: instance
#                  num_test: 202599                        	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [SingleDataset] was created
# initialize network with normal
# model [TestModel] was created
# loading the model from ./checkpoints\face2sketch\latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.410 M
# -----------------------------------------------
# creating web directory ./results/face2sketch\test_latest
# processing (0000)-th image... ['./datasets/face2sketch/trainA\\000001.png']
# processing (0005)-th image... ['./datasets/face2sketch/trainA\\000006.png']
# processing (0010)-th image... ['./datasets/face2sketch/trainA\\000011.png']
# processing (0015)-th image... ['./datasets/face2sketch/trainA\\000016.png']
# processing (0020)-th image... ['./datasets/face2sketch/trainA\\000021.png']
# processing (0025)-th image... ['./datasets/face2sketch/trainA\\000026.png']
# processing (0030)-th image... ['./datasets/face2sketch/trainA\\000031.png']
# processing (0035)-th image... ['./datasets/face2sketch/trainA\\000036.png']
# processing (0040)-th image... ['./datasets/face2sketch/trainA\\000041.png']
# processing (0045)-th image... ['./datasets/face2sketch/trainA\\000046.png']
# processing (0050)-th image... ['./datasets/face2sketch/trainA\\000051.png']
# processing (0055)-th image... ['./datasets/face2sketch/trainA\\000056.png']
# processing (0060)-th image... ['./datasets/face2sketch/trainA\\000061.png']
# processing (0065)-th image... ['./datasets/face2sketch/trainA\\000066.png']
# processing (0070)-th image... ['./datasets/face2sketch/trainA\\000071.png']
# processing (0075)-th image... ['./datasets/face2sketch/trainA\\000076.png']
# processing (0080)-th image... ['./datasets/face2sketch/trainA\\000081.png']
# processing (0085)-th image... ['./datasets/face2sketch/trainA\\000086.png']
# processing (0090)-th image... ['./datasets/face2sketch/trainA\\000091.png']
# processing (0095)-th image... ['./datasets/face2sketch/trainA\\000096.png']
# processing (0100)-th image... ['./datasets/face2sketch/trainA\\000101.png']
# processing (0105)-th image... ['./datasets/face2sketch/trainA\\000106.png']
# processing (0110)-th image... ['./datasets/face2sketch/trainA\\000111.png']
# processing (0115)-th image... ['./datasets/face2sketch/trainA\\000116.png']
# processing (0120)-th image... ['./datasets/face2sketch/trainA\\000121.png']
# processing (0125)-th image... ['./datasets/face2sketch/trainA\\000126.png']
# processing (0130)-th image... ['./datasets/face2sketch/trainA\\000131.png']
# processing (0135)-th image... ['./datasets/face2sketch/trainA\\000136.png']
# processing (0140)-th image... ['./datasets/face2sketch/trainA\\000141.png']
# processing (0145)-th image... ['./datasets/face2sketch/trainA\\000146.png']
# processing (0150)-th image... ['./datasets/face2sketch/trainA\\000151.png']
# processing (0155)-th image... ['./datasets/face2sketch/trainA\\000156.png']
# processing (0160)-th image... ['./datasets/face2sketch/trainA\\000161.png']
# processing (0165)-th image... ['./datasets/face2sketch/trainA\\000166.png']
# processing (0170)-th image... ['./datasets/face2sketch/trainA\\000171.png']
# processing (0175)-th image... ['./datasets/face2sketch/trainA\\000176.png']
# processing (0180)-th image... ['./datasets/face2sketch/trainA\\000181.png']
# processing (0185)-th image... ['./datasets/face2sketch/trainA\\000186.png']
# processing (0190)-th image... ['./datasets/face2sketch/trainA\\000191.png']
# processing (0195)-th image... ['./datasets/face2sketch/trainA\\000196.png']
# processing (0200)-th image... ['./datasets/face2sketch/trainA\\000201.png']
# processing (0205)-th image... ['./datasets/face2sketch/trainA\\000206.png']
# processing (0210)-th image... ['./datasets/face2sketch/trainA\\000211.png']
# processing (0215)-th image... ['./datasets/face2sketch/trainA\\000216.png']
# processing (0220)-th image... ['./datasets/face2sketch/trainA\\000221.png']
# processing (0225)-th image... ['./datasets/face2sketch/trainA\\000226.png']
# processing (0230)-th image... ['./datasets/face2sketch/trainA\\000231.png']
# processing (0235)-th image... ['./datasets/face2sketch/trainA\\000236.png']
# processing (0240)-th image... ['./datasets/face2sketch/trainA\\000241.png']
# processing (0245)-th image... ['./datasets/face2sketch/trainA\\000246.png']
# processing (0250)-th image... ['./datasets/face2sketch/trainA\\000251.png']
# processing (0255)-th image... ['./datasets/face2sketch/trainA\\000256.png']
# processing (0260)-th image... ['./datasets/face2sketch/trainA\\000261.png']
# processing (0265)-th image... ['./datasets/face2sketch/trainA\\000266.png']
# processing (0270)-th image... ['./datasets/face2sketch/trainA\\000271.png']
# processing (0275)-th image... ['./datasets/face2sketch/trainA\\000276.png']
# processing (0280)-th image... ['./datasets/face2sketch/trainA\\000281.png']
# processing (0285)-th image... ['./datasets/face2sketch/trainA\\000286.png']
# processing (0290)-th image... ['./datasets/face2sketch/trainA\\000291.png']
# processing (0295)-th image... ['./datasets/face2sketch/trainA\\000296.png']
# processing (0300)-th image... ['./datasets/face2sketch/trainA\\000301.png']
# processing (0305)-th image... ['./datasets/face2sketch/trainA\\000306.png']
# processing (0310)-th image... ['./datasets/face2sketch/trainA\\000311.png']
# processing (0315)-th image... ['./datasets/face2sketch/trainA\\000316.png']
# processing (0320)-th image... ['./datasets/face2sketch/trainA\\000321.png']
# processing (0325)-th image... ['./datasets/face2sketch/trainA\\000326.png']
# processing (0330)-th image... ['./datasets/face2sketch/trainA\\000331.png']
# processing (0335)-th image... ['./datasets/face2sketch/trainA\\000336.png']
# processing (0340)-th image... ['./datasets/face2sketch/trainA\\000341.png']
# processing (0345)-th image... ['./datasets/face2sketch/trainA\\000346.png']
# processing (0350)-th image... ['./datasets/face2sketch/trainA\\000351.png']
# processing (0355)-th image... ['./datasets/face2sketch/trainA\\000356.png']
# processing (0360)-th image... ['./datasets/face2sketch/trainA\\000361.png']
# processing (0365)-th image... ['./datasets/face2sketch/trainA\\000366.png']
# processing (0370)-th image... ['./datasets/face2sketch/trainA\\000371.png']
# processing (0375)-th image... ['./datasets/face2sketch/trainA\\000376.png']
# processing (0380)-th image... ['./datasets/face2sketch/trainA\\000381.png']
# processing (0385)-th image... ['./datasets/face2sketch/trainA\\000386.png']
# processing (0390)-th image... ['./datasets/face2sketch/trainA\\000391.png']
# processing (0395)-th image... ['./datasets/face2sketch/trainA\\000396.png']
# processing (0400)-th image... ['./datasets/face2sketch/trainA\\000401.png']
# processing (0405)-th image... ['./datasets/face2sketch/trainA\\000406.png']
# processing (0410)-th image... ['./datasets/face2sketch/trainA\\000411.png']
# processing (0415)-th image... ['./datasets/face2sketch/trainA\\000416.png']
# processing (0420)-th image... ['./datasets/face2sketch/trainA\\000421.png']
# processing (0425)-th image... ['./datasets/face2sketch/trainA\\000426.png']
# processing (0430)-th image... ['./datasets/face2sketch/trainA\\000431.png']
# processing (0435)-th image... ['./datasets/face2sketch/trainA\\000436.png']
# processing (0440)-th image... ['./datasets/face2sketch/trainA\\000441.png']
# processing (0445)-th image... ['./datasets/face2sketch/trainA\\000446.png']
# processing (0450)-th image... ['./datasets/face2sketch/trainA\\000451.png']
# processing (0455)-th image... ['./datasets/face2sketch/trainA\\000456.png']
# processing (0460)-th image... ['./datasets/face2sketch/trainA\\000461.png']
# processing (0465)-th image... ['./datasets/face2sketch/trainA\\000466.png']
# processing (0470)-th image... ['./datasets/face2sketch/trainA\\000471.png']
# processing (0475)-th image... ['./datasets/face2sketch/trainA\\000476.png']
# processing (0480)-th image... ['./datasets/face2sketch/trainA\\000481.png']
# processing (0485)-th image... ['./datasets/face2sketch/trainA\\000486.png']
# processing (0490)-th image... ['./datasets/face2sketch/trainA\\000491.png']
# processing (0495)-th image... ['./datasets/face2sketch/trainA\\000496.png']
# processing (0500)-th image... ['./datasets/face2sketch/trainA\\000501.png']
# processing (0505)-th image... ['./datasets/face2sketch/trainA\\000506.png']
# processing (0510)-th image... ['./datasets/face2sketch/trainA\\000511.png']
# processing (0515)-th image... ['./datasets/face2sketch/trainA\\000516.png']
# processing (0520)-th image... ['./datasets/face2sketch/trainA\\000521.png']
# processing (0525)-th image... ['./datasets/face2sketch/trainA\\000526.png']
# processing (0530)-th image... ['./datasets/face2sketch/trainA\\000531.png']
# processing (0535)-th image... ['./datasets/face2sketch/trainA\\000536.png']
# processing (0540)-th image... ['./datasets/face2sketch/trainA\\000541.png']
# processing (0545)-th image... ['./datasets/face2sketch/trainA\\000546.png']
# processing (0550)-th image... ['./datasets/face2sketch/trainA\\000551.png']
# processing (0555)-th image... ['./datasets/face2sketch/trainA\\000556.png']
# processing (0560)-th image... ['./datasets/face2sketch/trainA\\000561.png']
# processing (0565)-th image... ['./datasets/face2sketch/trainA\\000566.png']
# processing (0570)-th image... ['./datasets/face2sketch/trainA\\000571.png']
# processing (0575)-th image... ['./datasets/face2sketch/trainA\\000576.png']
# processing (0580)-th image... ['./datasets/face2sketch/trainA\\000581.png']
# processing (0585)-th image... ['./datasets/face2sketch/trainA\\000586.png']
# processing (0590)-th image... ['./datasets/face2sketch/trainA\\000591.png']
# processing (0595)-th image... ['./datasets/face2sketch/trainA\\000596.png']
# processing (0600)-th image... ['./datasets/face2sketch/trainA\\000601.png']
# processing (0605)-th image... ['./datasets/face2sketch/trainA\\000606.png']
# processing (0610)-th image... ['./datasets/face2sketch/trainA\\000611.png']
# processing (0615)-th image... ['./datasets/face2sketch/trainA\\000616.png']
# processing (0620)-th image... ['./datasets/face2sketch/trainA\\000621.png']
# processing (0625)-th image... ['./datasets/face2sketch/trainA\\000626.png']
# processing (0630)-th image... ['./datasets/face2sketch/trainA\\000631.png']
# processing (0635)-th image... ['./datasets/face2sketch/trainA\\000636.png']
# processing (0640)-th image... ['./datasets/face2sketch/trainA\\000641.png']
# processing (0645)-th image... ['./datasets/face2sketch/trainA\\000646.png']
# processing (0650)-th image... ['./datasets/face2sketch/trainA\\000651.png']
# processing (0655)-th image... ['./datasets/face2sketch/trainA\\000656.png']
# processing (0660)-th image... ['./datasets/face2sketch/trainA\\000661.png']
# processing (0665)-th image... ['./datasets/face2sketch/trainA\\000666.png']
# processing (0670)-th image... ['./datasets/face2sketch/trainA\\000671.png']
# processing (0675)-th image... ['./datasets/face2sketch/trainA\\000676.png']
# processing (0680)-th image... ['./datasets/face2sketch/trainA\\000681.png']
# processing (0685)-th image... ['./datasets/face2sketch/trainA\\000686.png']
# processing (0690)-th image... ['./datasets/face2sketch/trainA\\000691.png']
# processing (0695)-th image... ['./datasets/face2sketch/trainA\\000696.png']
# processing (0700)-th image... ['./datasets/face2sketch/trainA\\000701.png']
# processing (0705)-th image... ['./datasets/face2sketch/trainA\\000706.png']
# processing (0710)-th image... ['./datasets/face2sketch/trainA\\000711.png']
# processing (0715)-th image... ['./datasets/face2sketch/trainA\\000716.png']
# processing (0720)-th image... ['./datasets/face2sketch/trainA\\000721.png']
# processing (0725)-th image... ['./datasets/face2sketch/trainA\\000726.png']
# processing (0730)-th image... ['./datasets/face2sketch/trainA\\000731.png']
# processing (0735)-th image... ['./datasets/face2sketch/trainA\\000736.png']
# processing (0740)-th image... ['./datasets/face2sketch/trainA\\000741.png']
# processing (0745)-th image... ['./datasets/face2sketch/trainA\\000746.png']
# processing (0750)-th image... ['./datasets/face2sketch/trainA\\000751.png']
# processing (0755)-th image... ['./datasets/face2sketch/trainA\\000756.png']
# processing (0760)-th image... ['./datasets/face2sketch/trainA\\000761.png']
# processing (0765)-th image... ['./datasets/face2sketch/trainA\\000766.png']
# processing (0770)-th image... ['./datasets/face2sketch/trainA\\000771.png']
# processing (0775)-th image... ['./datasets/face2sketch/trainA\\000776.png']
# processing (0780)-th image... ['./datasets/face2sketch/trainA\\000781.png']
# processing (0785)-th image... ['./datasets/face2sketch/trainA\\000786.png']
# processing (0790)-th image... ['./datasets/face2sketch/trainA\\000791.png']
# processing (0795)-th image... ['./datasets/face2sketch/trainA\\000796.png']
# processing (0800)-th image... ['./datasets/face2sketch/trainA\\000801.png']
# processing (0805)-th image... ['./datasets/face2sketch/trainA\\000806.png']
# processing (0810)-th image... ['./datasets/face2sketch/trainA\\000811.png']
# processing (0815)-th image... ['./datasets/face2sketch/trainA\\000816.png']
# processing (0820)-th image... ['./datasets/face2sketch/trainA\\000821.png']
# processing (0825)-th image... ['./datasets/face2sketch/trainA\\000826.png']
# processing (0830)-th image... ['./datasets/face2sketch/trainA\\000831.png']
# processing (0835)-th image... ['./datasets/face2sketch/trainA\\000836.png']
# processing (0840)-th image... ['./datasets/face2sketch/trainA\\000841.png']
# processing (0845)-th image... ['./datasets/face2sketch/trainA\\000846.png']
# processing (0850)-th image... ['./datasets/face2sketch/trainA\\000851.png']
# processing (0855)-th image... ['./datasets/face2sketch/trainA\\000856.png']
# processing (0860)-th image... ['./datasets/face2sketch/trainA\\000861.png']
# processing (0865)-th image... ['./datasets/face2sketch/trainA\\000866.png']
# processing (0870)-th image... ['./datasets/face2sketch/trainA\\000871.png']
# processing (0875)-th image... ['./datasets/face2sketch/trainA\\000876.png']
# processing (0880)-th image... ['./datasets/face2sketch/trainA\\000881.png']
# processing (0885)-th image... ['./datasets/face2sketch/trainA\\000886.png']
# processing (0890)-th image... ['./datasets/face2sketch/trainA\\000891.png']
# processing (0895)-th image... ['./datasets/face2sketch/trainA\\000896.png']
# processing (0900)-th image... ['./datasets/face2sketch/trainA\\000901.png']
# processing (0905)-th image... ['./datasets/face2sketch/trainA\\000906.png']
# processing (0910)-th image... ['./datasets/face2sketch/trainA\\000911.png']
# processing (0915)-th image... ['./datasets/face2sketch/trainA\\000916.png']
# processing (0920)-th image... ['./datasets/face2sketch/trainA\\000921.png']
# processing (0925)-th image... ['./datasets/face2sketch/trainA\\000926.png']
# processing (0930)-th image... ['./datasets/face2sketch/trainA\\000931.png']
# processing (0935)-th image... ['./datasets/face2sketch/trainA\\000936.png']
# processing (0940)-th image... ['./datasets/face2sketch/trainA\\000941.png']
# processing (0945)-th image... ['./datasets/face2sketch/trainA\\000946.png']
# processing (0950)-th image... ['./datasets/face2sketch/trainA\\000951.png']
# processing (0955)-th image... ['./datasets/face2sketch/trainA\\000956.png']
# processing (0960)-th image... ['./datasets/face2sketch/trainA\\000961.png']
# processing (0965)-th image... ['./datasets/face2sketch/trainA\\000966.png']
# processing (0970)-th image... ['./datasets/face2sketch/trainA\\000971.png']
# processing (0975)-th image... ['./datasets/face2sketch/trainA\\000976.png']
# processing (0980)-th image... ['./datasets/face2sketch/trainA\\000981.png']
# processing (0985)-th image... ['./datasets/face2sketch/trainA\\000986.png']
# processing (0990)-th image... ['./datasets/face2sketch/trainA\\000991.png']
# processing (0995)-th image... ['./datasets/face2sketch/trainA\\000996.png']
# processing (1000)-th image... ['./datasets/face2sketch/trainA\\001001.png']
# processing (1005)-th image... ['./datasets/face2sketch/trainA\\001006.png']
# processing (1010)-th image... ['./datasets/face2sketch/trainA\\001011.png']
# processing (1015)-th image... ['./datasets/face2sketch/trainA\\001016.png']
# processing (1020)-th image... ['./datasets/face2sketch/trainA\\001021.png']
# processing (1025)-th image... ['./datasets/face2sketch/trainA\\001026.png']
# processing (1030)-th image... ['./datasets/face2sketch/trainA\\001031.png']
# processing (1035)-th image... ['./datasets/face2sketch/trainA\\001036.png']
# processing (1040)-th image... ['./datasets/face2sketch/trainA\\001041.png']
# processing (1045)-th image... ['./datasets/face2sketch/trainA\\001046.png']
# processing (1050)-th image... ['./datasets/face2sketch/trainA\\001051.png']
# processing (1055)-th image... ['./datasets/face2sketch/trainA\\001056.png']
# processing (1060)-th image... ['./datasets/face2sketch/trainA\\001061.png']
# processing (1065)-th image... ['./datasets/face2sketch/trainA\\001066.png']
# processing (1070)-th image... ['./datasets/face2sketch/trainA\\001071.png']
# processing (1075)-th image... ['./datasets/face2sketch/trainA\\001076.png']
# processing (1080)-th image... ['./datasets/face2sketch/trainA\\001081.png']
# processing (1085)-th image... ['./datasets/face2sketch/trainA\\001086.png']
# processing (1090)-th image... ['./datasets/face2sketch/trainA\\001091.png']
# processing (1095)-th image... ['./datasets/face2sketch/trainA\\001096.png']
# processing (1100)-th image... ['./datasets/face2sketch/trainA\\001101.png']
# processing (1105)-th image... ['./datasets/face2sketch/trainA\\001106.png']
# processing (1110)-th image... ['./datasets/face2sketch/trainA\\001111.png']
# processing (1115)-th image... ['./datasets/face2sketch/trainA\\001116.png']
# processing (1120)-th image... ['./datasets/face2sketch/trainA\\001121.png']
# processing (1125)-th image... ['./datasets/face2sketch/trainA\\001126.png']
# processing (1130)-th image... ['./datasets/face2sketch/trainA\\001131.png']
# processing (1135)-th image... ['./datasets/face2sketch/trainA\\001136.png']
# processing (1140)-th image... ['./datasets/face2sketch/trainA\\001141.png']
# processing (1145)-th image... ['./datasets/face2sketch/trainA\\001146.png']
# processing (1150)-th image... ['./datasets/face2sketch/trainA\\001151.png']
# processing (1155)-th image... ['./datasets/face2sketch/trainA\\001156.png']
# processing (1160)-th image... ['./datasets/face2sketch/trainA\\001161.png']
# processing (1165)-th image... ['./datasets/face2sketch/trainA\\001166.png']
# processing (1170)-th image... ['./datasets/face2sketch/trainA\\001171.png']
# processing (1175)-th image... ['./datasets/face2sketch/trainA\\001176.png']
# processing (1180)-th image... ['./datasets/face2sketch/trainA\\001181.png']
# processing (1185)-th image... ['./datasets/face2sketch/trainA\\001186.png']
# processing (1190)-th image... ['./datasets/face2sketch/trainA\\001191.png']
# processing (1195)-th image... ['./datasets/face2sketch/trainA\\001196.png']
# processing (1200)-th image... ['./datasets/face2sketch/trainA\\001201.png']
# processing (1205)-th image... ['./datasets/face2sketch/trainA\\001206.png']
# processing (1210)-th image... ['./datasets/face2sketch/trainA\\001211.png']
# processing (1215)-th image... ['./datasets/face2sketch/trainA\\001216.png']
# processing (1220)-th image... ['./datasets/face2sketch/trainA\\001221.png']
# processing (1225)-th image... ['./datasets/face2sketch/trainA\\001226.png']
# processing (1230)-th image... ['./datasets/face2sketch/trainA\\001231.png']
# processing (1235)-th image... ['./datasets/face2sketch/trainA\\001236.png']
# processing (1240)-th image... ['./datasets/face2sketch/trainA\\001241.png']
# processing (1245)-th image... ['./datasets/face2sketch/trainA\\001246.png']
# processing (1250)-th image... ['./datasets/face2sketch/trainA\\001251.png']
# processing (1255)-th image... ['./datasets/face2sketch/trainA\\001256.png']
# processing (1260)-th image... ['./datasets/face2sketch/trainA\\001261.png']
# processing (1265)-th image... ['./datasets/face2sketch/trainA\\001266.png']
# processing (1270)-th image... ['./datasets/face2sketch/trainA\\001271.png']
# processing (1275)-th image... ['./datasets/face2sketch/trainA\\001276.png']
# processing (1280)-th image... ['./datasets/face2sketch/trainA\\001281.png']
# processing (1285)-th image... ['./datasets/face2sketch/trainA\\001286.png']
# processing (1290)-th image... ['./datasets/face2sketch/trainA\\001291.png']
# processing (1295)-th image... ['./datasets/face2sketch/trainA\\001296.png']
# processing (1300)-th image... ['./datasets/face2sketch/trainA\\001301.png']
# processing (1305)-th image... ['./datasets/face2sketch/trainA\\001306.png']
# processing (1310)-th image... ['./datasets/face2sketch/trainA\\001311.png']
# processing (1315)-th image... ['./datasets/face2sketch/trainA\\001316.png']
# processing (1320)-th image... ['./datasets/face2sketch/trainA\\001321.png']
# processing (1325)-th image... ['./datasets/face2sketch/trainA\\001326.png']
# processing (1330)-th image... ['./datasets/face2sketch/trainA\\001331.png']
# processing (1335)-th image... ['./datasets/face2sketch/trainA\\001336.png']
# processing (1340)-th image... ['./datasets/face2sketch/trainA\\001341.png']
# processing (1345)-th image... ['./datasets/face2sketch/trainA\\001346.png']
# processing (1350)-th image... ['./datasets/face2sketch/trainA\\001351.png']
# processing (1355)-th image... ['./datasets/face2sketch/trainA\\001356.png']
# processing (1360)-th image... ['./datasets/face2sketch/trainA\\001361.png']
# processing (1365)-th image... ['./datasets/face2sketch/trainA\\001366.png']
# processing (1370)-th image... ['./datasets/face2sketch/trainA\\001371.png']
# processing (1375)-th image... ['./datasets/face2sketch/trainA\\001376.png']
# processing (1380)-th image... ['./datasets/face2sketch/trainA\\001381.png']
# processing (1385)-th image... ['./datasets/face2sketch/trainA\\001386.png']
# processing (1390)-th image... ['./datasets/face2sketch/trainA\\001391.png']
# processing (1395)-th image... ['./datasets/face2sketch/trainA\\001396.png']
# processing (1400)-th image... ['./datasets/face2sketch/trainA\\001401.png']
# processing (1405)-th image... ['./datasets/face2sketch/trainA\\001406.png']
# processing (1410)-th image... ['./datasets/face2sketch/trainA\\001411.png']
# processing (1415)-th image... ['./datasets/face2sketch/trainA\\001416.png']
# processing (1420)-th image... ['./datasets/face2sketch/trainA\\001421.png']
# processing (1425)-th image... ['./datasets/face2sketch/trainA\\001426.png']
# processing (1430)-th image... ['./datasets/face2sketch/trainA\\001431.png']
# processing (1435)-th image... ['./datasets/face2sketch/trainA\\001436.png']
# processing (1440)-th image... ['./datasets/face2sketch/trainA\\001441.png']
# processing (1445)-th image... ['./datasets/face2sketch/trainA\\001446.png']
# processing (1450)-th image... ['./datasets/face2sketch/trainA\\001451.png']
# processing (1455)-th image... ['./datasets/face2sketch/trainA\\001456.png']
# processing (1460)-th image... ['./datasets/face2sketch/trainA\\001461.png']
# processing (1465)-th image... ['./datasets/face2sketch/trainA\\001466.png']
# processing (1470)-th image... ['./datasets/face2sketch/trainA\\001471.png']
# processing (1475)-th image... ['./datasets/face2sketch/trainA\\001476.png']
# processing (1480)-th image... ['./datasets/face2sketch/trainA\\001481.png']
# processing (1485)-th image... ['./datasets/face2sketch/trainA\\001486.png']
# processing (1490)-th image... ['./datasets/face2sketch/trainA\\001491.png']
# processing (1495)-th image... ['./datasets/face2sketch/trainA\\001496.png']
# processing (1500)-th image... ['./datasets/face2sketch/trainA\\001501.png']
# processing (1505)-th image... ['./datasets/face2sketch/trainA\\001506.png']
# processing (1510)-th image... ['./datasets/face2sketch/trainA\\001511.png']
# processing (1515)-th image... ['./datasets/face2sketch/trainA\\001516.png']
# processing (1520)-th image... ['./datasets/face2sketch/trainA\\001521.png']
# processing (1525)-th image... ['./datasets/face2sketch/trainA\\001526.png']
# processing (1530)-th image... ['./datasets/face2sketch/trainA\\001531.png']
# processing (1535)-th image... ['./datasets/face2sketch/trainA\\001536.png']
# processing (1540)-th image... ['./datasets/face2sketch/trainA\\001541.png']
# processing (1545)-th image... ['./datasets/face2sketch/trainA\\001546.png']
# processing (1550)-th image... ['./datasets/face2sketch/trainA\\001551.png']
# processing (1555)-th image... ['./datasets/face2sketch/trainA\\001556.png']
# processing (1560)-th image... ['./datasets/face2sketch/trainA\\001561.png']
# processing (1565)-th image... ['./datasets/face2sketch/trainA\\001566.png']
# processing (1570)-th image... ['./datasets/face2sketch/trainA\\001571.png']
# processing (1575)-th image... ['./datasets/face2sketch/trainA\\001576.png']
# processing (1580)-th image... ['./datasets/face2sketch/trainA\\001581.png']
# processing (1585)-th image... ['./datasets/face2sketch/trainA\\001586.png']
# processing (1590)-th image... ['./datasets/face2sketch/trainA\\001591.png']
# processing (1595)-th image... ['./datasets/face2sketch/trainA\\001596.png']
# processing (1600)-th image... ['./datasets/face2sketch/trainA\\001601.png']
# processing (1605)-th image... ['./datasets/face2sketch/trainA\\001606.png']
# processing (1610)-th image... ['./datasets/face2sketch/trainA\\001611.png']
# processing (1615)-th image... ['./datasets/face2sketch/trainA\\001616.png']
# processing (1620)-th image... ['./datasets/face2sketch/trainA\\001621.png']
# processing (1625)-th image... ['./datasets/face2sketch/trainA\\001626.png']
# processing (1630)-th image... ['./datasets/face2sketch/trainA\\001631.png']
# processing (1635)-th image... ['./datasets/face2sketch/trainA\\001636.png']
# processing (1640)-th image... ['./datasets/face2sketch/trainA\\001641.png']
# processing (1645)-th image... ['./datasets/face2sketch/trainA\\001646.png']
# processing (1650)-th image... ['./datasets/face2sketch/trainA\\001651.png']
# processing (1655)-th image... ['./datasets/face2sketch/trainA\\001656.png']
# processing (1660)-th image... ['./datasets/face2sketch/trainA\\001661.png']
# processing (1665)-th image... ['./datasets/face2sketch/trainA\\001666.png']
# processing (1670)-th image... ['./datasets/face2sketch/trainA\\001671.png']
# processing (1675)-th image... ['./datasets/face2sketch/trainA\\001676.png']
# processing (1680)-th image... ['./datasets/face2sketch/trainA\\001681.png']
# processing (1685)-th image... ['./datasets/face2sketch/trainA\\001686.png']
# processing (1690)-th image... ['./datasets/face2sketch/trainA\\001691.png']
# processing (1695)-th image... ['./datasets/face2sketch/trainA\\001696.png']
# processing (1700)-th image... ['./datasets/face2sketch/trainA\\001701.png']
# processing (1705)-th image... ['./datasets/face2sketch/trainA\\001706.png']
# processing (1710)-th image... ['./datasets/face2sketch/trainA\\001711.png']
# processing (1715)-th image... ['./datasets/face2sketch/trainA\\001716.png']
# processing (1720)-th image... ['./datasets/face2sketch/trainA\\001721.png']
# processing (1725)-th image... ['./datasets/face2sketch/trainA\\001726.png']
# processing (1730)-th image... ['./datasets/face2sketch/trainA\\001731.png']
# processing (1735)-th image... ['./datasets/face2sketch/trainA\\001736.png']
# processing (1740)-th image... ['./datasets/face2sketch/trainA\\001741.png']
# processing (1745)-th image... ['./datasets/face2sketch/trainA\\001746.png']
# processing (1750)-th image... ['./datasets/face2sketch/trainA\\001751.png']
# processing (1755)-th image... ['./datasets/face2sketch/trainA\\001756.png']
# processing (1760)-th image... ['./datasets/face2sketch/trainA\\001761.png']
# processing (1765)-th image... ['./datasets/face2sketch/trainA\\001766.png']
# processing (1770)-th image... ['./datasets/face2sketch/trainA\\001771.png']
# processing (1775)-th image... ['./datasets/face2sketch/trainA\\001776.png']
# processing (1780)-th image... ['./datasets/face2sketch/trainA\\001781.png']
# processing (1785)-th image... ['./datasets/face2sketch/trainA\\001786.png']
# processing (1790)-th image... ['./datasets/face2sketch/trainA\\001791.png']
# processing (1795)-th image... ['./datasets/face2sketch/trainA\\001796.png']
# processing (1800)-th image... ['./datasets/face2sketch/trainA\\001801.png']
# processing (1805)-th image... ['./datasets/face2sketch/trainA\\001806.png']
# processing (1810)-th image... ['./datasets/face2sketch/trainA\\001811.png']
# processing (1815)-th image... ['./datasets/face2sketch/trainA\\001816.png']
# processing (1820)-th image... ['./datasets/face2sketch/trainA\\001821.png']
# processing (1825)-th image... ['./datasets/face2sketch/trainA\\001826.png']
# processing (1830)-th image... ['./datasets/face2sketch/trainA\\001831.png']
# processing (1835)-th image... ['./datasets/face2sketch/trainA\\001836.png']
# processing (1840)-th image... ['./datasets/face2sketch/trainA\\001841.png']
# processing (1845)-th image... ['./datasets/face2sketch/trainA\\001846.png']
# processing (1850)-th image... ['./datasets/face2sketch/trainA\\001851.png']
# processing (1855)-th image... ['./datasets/face2sketch/trainA\\001856.png']
# processing (1860)-th image... ['./datasets/face2sketch/trainA\\001861.png']
# processing (1865)-th image... ['./datasets/face2sketch/trainA\\001866.png']
# processing (1870)-th image... ['./datasets/face2sketch/trainA\\001871.png']
# processing (1875)-th image... ['./datasets/face2sketch/trainA\\001876.png']
# processing (1880)-th image... ['./datasets/face2sketch/trainA\\001881.png']
# processing (1885)-th image... ['./datasets/face2sketch/trainA\\001886.png']
# processing (1890)-th image... ['./datasets/face2sketch/trainA\\001891.png']
# processing (1895)-th image... ['./datasets/face2sketch/trainA\\001896.png']
# processing (1900)-th image... ['./datasets/face2sketch/trainA\\001901.png']
# processing (1905)-th image... ['./datasets/face2sketch/trainA\\001906.png']
# processing (1910)-th image... ['./datasets/face2sketch/trainA\\001911.png']
# processing (1915)-th image... ['./datasets/face2sketch/trainA\\001916.png']
# processing (1920)-th image... ['./datasets/face2sketch/trainA\\001921.png']
# processing (1925)-th image... ['./datasets/face2sketch/trainA\\001926.png']
# processing (1930)-th image... ['./datasets/face2sketch/trainA\\001931.png']
# processing (1935)-th image... ['./datasets/face2sketch/trainA\\001936.png']
# processing (1940)-th image... ['./datasets/face2sketch/trainA\\001941.png']
# processing (1945)-th image... ['./datasets/face2sketch/trainA\\001946.png']
# processing (1950)-th image... ['./datasets/face2sketch/trainA\\001951.png']
# processing (1955)-th image... ['./datasets/face2sketch/trainA\\001956.png']
# processing (1960)-th image... ['./datasets/face2sketch/trainA\\001961.png']
# processing (1965)-th image... ['./datasets/face2sketch/trainA\\001966.png']
# processing (1970)-th image... ['./datasets/face2sketch/trainA\\001971.png']
# processing (1975)-th image... ['./datasets/face2sketch/trainA\\001976.png']
# processing (1980)-th image... ['./datasets/face2sketch/trainA\\001981.png']
# processing (1985)-th image... ['./datasets/face2sketch/trainA\\001986.png']
# processing (1990)-th image... ['./datasets/face2sketch/trainA\\001991.png']
# processing (1995)-th image... ['./datasets/face2sketch/trainA\\001996.png']
# processing (2000)-th image... ['./datasets/face2sketch/trainA\\002001.png']
# processing (2005)-th image... ['./datasets/face2sketch/trainA\\002006.png']
# processing (2010)-th image... ['./datasets/face2sketch/trainA\\002011.png']
# processing (2015)-th image... ['./datasets/face2sketch/trainA\\002016.png']
# processing (2020)-th image... ['./datasets/face2sketch/trainA\\002021.png']
# processing (2025)-th image... ['./datasets/face2sketch/trainA\\002026.png']
# processing (2030)-th image... ['./datasets/face2sketch/trainA\\002031.png']
# processing (2035)-th image... ['./datasets/face2sketch/trainA\\002036.png']
# processing (2040)-th image... ['./datasets/face2sketch/trainA\\002041.png']
# processing (2045)-th image... ['./datasets/face2sketch/trainA\\002046.png']
# processing (2050)-th image... ['./datasets/face2sketch/trainA\\002051.png']
# processing (2055)-th image... ['./datasets/face2sketch/trainA\\002056.png']
# processing (2060)-th image... ['./datasets/face2sketch/trainA\\002061.png']
# processing (2065)-th image... ['./datasets/face2sketch/trainA\\002066.png']
# processing (2070)-th image... ['./datasets/face2sketch/trainA\\002071.png']
# processing (2075)-th image... ['./datasets/face2sketch/trainA\\002076.png']
# processing (2080)-th image... ['./datasets/face2sketch/trainA\\002081.png']
# processing (2085)-th image... ['./datasets/face2sketch/trainA\\002086.png']
# processing (2090)-th image... ['./datasets/face2sketch/trainA\\002091.png']
# processing (2095)-th image... ['./datasets/face2sketch/trainA\\002096.png']
# processing (2100)-th image... ['./datasets/face2sketch/trainA\\002101.png']
# processing (2105)-th image... ['./datasets/face2sketch/trainA\\002106.png']
# processing (2110)-th image... ['./datasets/face2sketch/trainA\\002111.png']
# processing (2115)-th image... ['./datasets/face2sketch/trainA\\002116.png']
# processing (2120)-th image... ['./datasets/face2sketch/trainA\\002121.png']
# processing (2125)-th image... ['./datasets/face2sketch/trainA\\002126.png']
# processing (2130)-th image... ['./datasets/face2sketch/trainA\\002131.png']
# processing (2135)-th image... ['./datasets/face2sketch/trainA\\002136.png']
# processing (2140)-th image... ['./datasets/face2sketch/trainA\\002141.png']
# processing (2145)-th image... ['./datasets/face2sketch/trainA\\002146.png']
# processing (2150)-th image... ['./datasets/face2sketch/trainA\\002151.png']
# processing (2155)-th image... ['./datasets/face2sketch/trainA\\002156.png']
# processing (2160)-th image... ['./datasets/face2sketch/trainA\\002161.png']
# processing (2165)-th image... ['./datasets/face2sketch/trainA\\002166.png']
# processing (2170)-th image... ['./datasets/face2sketch/trainA\\002171.png']
# processing (2175)-th image... ['./datasets/face2sketch/trainA\\002176.png']
# processing (2180)-th image... ['./datasets/face2sketch/trainA\\002181.png']
# processing (2185)-th image... ['./datasets/face2sketch/trainA\\002186.png']
# processing (2190)-th image... ['./datasets/face2sketch/trainA\\002191.png']
# processing (2195)-th image... ['./datasets/face2sketch/trainA\\002196.png']
# processing (2200)-th image... ['./datasets/face2sketch/trainA\\002201.png']
# processing (2205)-th image... ['./datasets/face2sketch/trainA\\002206.png']
# processing (2210)-th image... ['./datasets/face2sketch/trainA\\002211.png']
# processing (2215)-th image... ['./datasets/face2sketch/trainA\\002216.png']
# processing (2220)-th image... ['./datasets/face2sketch/trainA\\002221.png']
# processing (2225)-th image... ['./datasets/face2sketch/trainA\\002226.png']
# processing (2230)-th image... ['./datasets/face2sketch/trainA\\002231.png']
# processing (2235)-th image... ['./datasets/face2sketch/trainA\\002236.png']
# processing (2240)-th image... ['./datasets/face2sketch/trainA\\002241.png']
# processing (2245)-th image... ['./datasets/face2sketch/trainA\\002246.png']
# processing (2250)-th image... ['./datasets/face2sketch/trainA\\002251.png']
# processing (2255)-th image... ['./datasets/face2sketch/trainA\\002256.png']
# processing (2260)-th image... ['./datasets/face2sketch/trainA\\002261.png']
# processing (2265)-th image... ['./datasets/face2sketch/trainA\\002266.png']
# processing (2270)-th image... ['./datasets/face2sketch/trainA\\002271.png']
# processing (2275)-th image... ['./datasets/face2sketch/trainA\\002276.png']
# processing (2280)-th image... ['./datasets/face2sketch/trainA\\002281.png']
# processing (2285)-th image... ['./datasets/face2sketch/trainA\\002286.png']
# processing (2290)-th image... ['./datasets/face2sketch/trainA\\002291.png']
# processing (2295)-th image... ['./datasets/face2sketch/trainA\\002296.png']
# processing (2300)-th image... ['./datasets/face2sketch/trainA\\002301.png']
# processing (2305)-th image... ['./datasets/face2sketch/trainA\\002306.png']
# processing (2310)-th image... ['./datasets/face2sketch/trainA\\002311.png']
# processing (2315)-th image... ['./datasets/face2sketch/trainA\\002316.png']
# processing (2320)-th image... ['./datasets/face2sketch/trainA\\002321.png']
# processing (2325)-th image... ['./datasets/face2sketch/trainA\\002326.png']
# processing (2330)-th image... ['./datasets/face2sketch/trainA\\002331.png']
# processing (2335)-th image... ['./datasets/face2sketch/trainA\\002336.png']
# processing (2340)-th image... ['./datasets/face2sketch/trainA\\002341.png']
# processing (2345)-th image... ['./datasets/face2sketch/trainA\\002346.png']
# processing (2350)-th image... ['./datasets/face2sketch/trainA\\002351.png']
# processing (2355)-th image... ['./datasets/face2sketch/trainA\\002356.png']
# processing (2360)-th image... ['./datasets/face2sketch/trainA\\002361.png']
# processing (2365)-th image... ['./datasets/face2sketch/trainA\\002366.png']
# processing (2370)-th image... ['./datasets/face2sketch/trainA\\002371.png']
# processing (2375)-th image... ['./datasets/face2sketch/trainA\\002376.png']
# processing (2380)-th image... ['./datasets/face2sketch/trainA\\002381.png']
# processing (2385)-th image... ['./datasets/face2sketch/trainA\\002386.png']
# processing (2390)-th image... ['./datasets/face2sketch/trainA\\002391.png']
# processing (2395)-th image... ['./datasets/face2sketch/trainA\\002396.png']
# processing (2400)-th image... ['./datasets/face2sketch/trainA\\002401.png']
# processing (2405)-th image... ['./datasets/face2sketch/trainA\\002406.png']
# processing (2410)-th image... ['./datasets/face2sketch/trainA\\002411.png']
# processing (2415)-th image... ['./datasets/face2sketch/trainA\\002416.png']
# processing (2420)-th image... ['./datasets/face2sketch/trainA\\002421.png']
# processing (2425)-th image... ['./datasets/face2sketch/trainA\\002426.png']
# processing (2430)-th image... ['./datasets/face2sketch/trainA\\002431.png']
# processing (2435)-th image... ['./datasets/face2sketch/trainA\\002436.png']
# processing (2440)-th image... ['./datasets/face2sketch/trainA\\002441.png']
# processing (2445)-th image... ['./datasets/face2sketch/trainA\\002446.png']
# processing (2450)-th image... ['./datasets/face2sketch/trainA\\002451.png']
# processing (2455)-th image... ['./datasets/face2sketch/trainA\\002456.png']
# processing (2460)-th image... ['./datasets/face2sketch/trainA\\002461.png']
# processing (2465)-th image... ['./datasets/face2sketch/trainA\\002466.png']
# processing (2470)-th image... ['./datasets/face2sketch/trainA\\002471.png']
# processing (2475)-th image... ['./datasets/face2sketch/trainA\\002476.png']
# processing (2480)-th image... ['./datasets/face2sketch/trainA\\002481.png']
# processing (2485)-th image... ['./datasets/face2sketch/trainA\\002486.png']
# processing (2490)-th image... ['./datasets/face2sketch/trainA\\002491.png']
# processing (2495)-th image... ['./datasets/face2sketch/trainA\\002496.png']
# processing (2500)-th image... ['./datasets/face2sketch/trainA\\002501.png']
# processing (2505)-th image... ['./datasets/face2sketch/trainA\\002506.png']
# processing (2510)-th image... ['./datasets/face2sketch/trainA\\002511.png']
# processing (2515)-th image... ['./datasets/face2sketch/trainA\\002516.png']
# processing (2520)-th image... ['./datasets/face2sketch/trainA\\002521.png']
# processing (2525)-th image... ['./datasets/face2sketch/trainA\\002526.png']
# processing (2530)-th image... ['./datasets/face2sketch/trainA\\002531.png']
# processing (2535)-th image... ['./datasets/face2sketch/trainA\\002536.png']
# processing (2540)-th image... ['./datasets/face2sketch/trainA\\002541.png']
# processing (2545)-th image... ['./datasets/face2sketch/trainA\\002546.png']
# processing (2550)-th image... ['./datasets/face2sketch/trainA\\002551.png']
# processing (2555)-th image... ['./datasets/face2sketch/trainA\\002556.png']
# processing (2560)-th image... ['./datasets/face2sketch/trainA\\002561.png']
# processing (2565)-th image... ['./datasets/face2sketch/trainA\\002566.png']
# processing (2570)-th image... ['./datasets/face2sketch/trainA\\002571.png']
# processing (2575)-th image... ['./datasets/face2sketch/trainA\\002576.png']
# processing (2580)-th image... ['./datasets/face2sketch/trainA\\002581.png']
# processing (2585)-th image... ['./datasets/face2sketch/trainA\\002586.png']
# processing (2590)-th image... ['./datasets/face2sketch/trainA\\002591.png']
# processing (2595)-th image... ['./datasets/face2sketch/trainA\\002596.png']
# processing (2600)-th image... ['./datasets/face2sketch/trainA\\002601.png']
# processing (2605)-th image... ['./datasets/face2sketch/trainA\\002606.png']
# processing (2610)-th image... ['./datasets/face2sketch/trainA\\002611.png']
# processing (2615)-th image... ['./datasets/face2sketch/trainA\\002616.png']
# processing (2620)-th image... ['./datasets/face2sketch/trainA\\002621.png']
# processing (2625)-th image... ['./datasets/face2sketch/trainA\\002626.png']
# processing (2630)-th image... ['./datasets/face2sketch/trainA\\002631.png']
# processing (2635)-th image... ['./datasets/face2sketch/trainA\\002636.png']
# processing (2640)-th image... ['./datasets/face2sketch/trainA\\002641.png']
# processing (2645)-th image... ['./datasets/face2sketch/trainA\\002646.png']
# processing (2650)-th image... ['./datasets/face2sketch/trainA\\002651.png']
# processing (2655)-th image... ['./datasets/face2sketch/trainA\\002656.png']
# processing (2660)-th image... ['./datasets/face2sketch/trainA\\002661.png']
# processing (2665)-th image... ['./datasets/face2sketch/trainA\\002666.png']
# processing (2670)-th image... ['./datasets/face2sketch/trainA\\002671.png']
# processing (2675)-th image... ['./datasets/face2sketch/trainA\\002676.png']
# processing (2680)-th image... ['./datasets/face2sketch/trainA\\002681.png']
# processing (2685)-th image... ['./datasets/face2sketch/trainA\\002686.png']
# processing (2690)-th image... ['./datasets/face2sketch/trainA\\002691.png']
# processing (2695)-th image... ['./datasets/face2sketch/trainA\\002696.png']
# processing (2700)-th image... ['./datasets/face2sketch/trainA\\002701.png']
# processing (2705)-th image... ['./datasets/face2sketch/trainA\\002706.png']
# processing (2710)-th image... ['./datasets/face2sketch/trainA\\002711.png']
# processing (2715)-th image... ['./datasets/face2sketch/trainA\\002716.png']
# processing (2720)-th image... ['./datasets/face2sketch/trainA\\002721.png']
# processing (2725)-th image... ['./datasets/face2sketch/trainA\\002726.png']
# processing (2730)-th image... ['./datasets/face2sketch/trainA\\002731.png']
# processing (2735)-th image... ['./datasets/face2sketch/trainA\\002736.png']
# processing (2740)-th image... ['./datasets/face2sketch/trainA\\002741.png']
# processing (2745)-th image... ['./datasets/face2sketch/trainA\\002746.png']
# processing (2750)-th image... ['./datasets/face2sketch/trainA\\002751.png']
# processing (2755)-th image... ['./datasets/face2sketch/trainA\\002756.png']
# processing (2760)-th image... ['./datasets/face2sketch/trainA\\002761.png']
# processing (2765)-th image... ['./datasets/face2sketch/trainA\\002766.png']
# processing (2770)-th image... ['./datasets/face2sketch/trainA\\002771.png']
# processing (2775)-th image... ['./datasets/face2sketch/trainA\\002776.png']
# processing (2780)-th image... ['./datasets/face2sketch/trainA\\002781.png']
# processing (2785)-th image... ['./datasets/face2sketch/trainA\\002786.png']
# processing (2790)-th image... ['./datasets/face2sketch/trainA\\002791.png']
# processing (2795)-th image... ['./datasets/face2sketch/trainA\\002796.png']
# processing (2800)-th image... ['./datasets/face2sketch/trainA\\002801.png']
# processing (2805)-th image... ['./datasets/face2sketch/trainA\\002806.png']
# processing (2810)-th image... ['./datasets/face2sketch/trainA\\002811.png']
# processing (2815)-th image... ['./datasets/face2sketch/trainA\\002816.png']
# processing (2820)-th image... ['./datasets/face2sketch/trainA\\002821.png']
# processing (2825)-th image... ['./datasets/face2sketch/trainA\\002826.png']
# processing (2830)-th image... ['./datasets/face2sketch/trainA\\002831.png']
# processing (2835)-th image... ['./datasets/face2sketch/trainA\\002836.png']
# processing (2840)-th image... ['./datasets/face2sketch/trainA\\002841.png']
# processing (2845)-th image... ['./datasets/face2sketch/trainA\\002846.png']
# processing (2850)-th image... ['./datasets/face2sketch/trainA\\002851.png']
# processing (2855)-th image... ['./datasets/face2sketch/trainA\\002856.png']
# processing (2860)-th image... ['./datasets/face2sketch/trainA\\002861.png']
# processing (2865)-th image... ['./datasets/face2sketch/trainA\\002866.png']
# processing (2870)-th image... ['./datasets/face2sketch/trainA\\002871.png']
# processing (2875)-th image... ['./datasets/face2sketch/trainA\\002876.png']
# processing (2880)-th image... ['./datasets/face2sketch/trainA\\002881.png']
# processing (2885)-th image... ['./datasets/face2sketch/trainA\\002886.png']
# processing (2890)-th image... ['./datasets/face2sketch/trainA\\002891.png']
# processing (2895)-th image... ['./datasets/face2sketch/trainA\\002896.png']
# processing (2900)-th image... ['./datasets/face2sketch/trainA\\002901.png']
# processing (2905)-th image... ['./datasets/face2sketch/trainA\\002906.png']
# processing (2910)-th image... ['./datasets/face2sketch/trainA\\002911.png']
# processing (2915)-th image... ['./datasets/face2sketch/trainA\\002916.png']
# processing (2920)-th image... ['./datasets/face2sketch/trainA\\002921.png']
# processing (2925)-th image... ['./datasets/face2sketch/trainA\\002926.png']
# processing (2930)-th image... ['./datasets/face2sketch/trainA\\002931.png']
# processing (2935)-th image... ['./datasets/face2sketch/trainA\\002936.png']
# processing (2940)-th image... ['./datasets/face2sketch/trainA\\002941.png']
# processing (2945)-th image... ['./datasets/face2sketch/trainA\\002946.png']
# processing (2950)-th image... ['./datasets/face2sketch/trainA\\002951.png']
# processing (2955)-th image... ['./datasets/face2sketch/trainA\\002956.png']
# processing (2960)-th image... ['./datasets/face2sketch/trainA\\002961.png']
# processing (2965)-th image... ['./datasets/face2sketch/trainA\\002966.png']
# ...
# processing (201575)-th image... ['./datasets/face2sketch/trainA\\201576.png']
# processing (201580)-th image... ['./datasets/face2sketch/trainA\\201581.png']
# processing (201585)-th image... ['./datasets/face2sketch/trainA\\201586.png']
# processing (201590)-th image... ['./datasets/face2sketch/trainA\\201591.png']
# processing (201595)-th image... ['./datasets/face2sketch/trainA\\201596.png']
# processing (201600)-th image... ['./datasets/face2sketch/trainA\\201601.png']
# processing (201605)-th image... ['./datasets/face2sketch/trainA\\201606.png']
# processing (201610)-th image... ['./datasets/face2sketch/trainA\\201611.png']
# processing (201615)-th image... ['./datasets/face2sketch/trainA\\201616.png']
# processing (201620)-th image... ['./datasets/face2sketch/trainA\\201621.png']
# processing (201625)-th image... ['./datasets/face2sketch/trainA\\201626.png']
# processing (201630)-th image... ['./datasets/face2sketch/trainA\\201631.png']
# processing (201635)-th image... ['./datasets/face2sketch/trainA\\201636.png']
# processing (201640)-th image... ['./datasets/face2sketch/trainA\\201641.png']
# processing (201645)-th image... ['./datasets/face2sketch/trainA\\201646.png']
# processing (201650)-th image... ['./datasets/face2sketch/trainA\\201651.png']
# processing (201655)-th image... ['./datasets/face2sketch/trainA\\201656.png']
# processing (201660)-th image... ['./datasets/face2sketch/trainA\\201661.png']
# processing (201665)-th image... ['./datasets/face2sketch/trainA\\201666.png']
# processing (201670)-th image... ['./datasets/face2sketch/trainA\\201671.png']
# processing (201675)-th image... ['./datasets/face2sketch/trainA\\201676.png']
# processing (201680)-th image... ['./datasets/face2sketch/trainA\\201681.png']
# processing (201685)-th image... ['./datasets/face2sketch/trainA\\201686.png']
# processing (201690)-th image... ['./datasets/face2sketch/trainA\\201691.png']
# processing (201695)-th image... ['./datasets/face2sketch/trainA\\201696.png']
# processing (201700)-th image... ['./datasets/face2sketch/trainA\\201701.png']
# processing (201705)-th image... ['./datasets/face2sketch/trainA\\201706.png']
# processing (201710)-th image... ['./datasets/face2sketch/trainA\\201711.png']
# processing (201715)-th image... ['./datasets/face2sketch/trainA\\201716.png']
# processing (201720)-th image... ['./datasets/face2sketch/trainA\\201721.png']
# processing (201725)-th image... ['./datasets/face2sketch/trainA\\201726.png']
# processing (201730)-th image... ['./datasets/face2sketch/trainA\\201731.png']
# processing (201735)-th image... ['./datasets/face2sketch/trainA\\201736.png']
# processing (201740)-th image... ['./datasets/face2sketch/trainA\\201741.png']
# processing (201745)-th image... ['./datasets/face2sketch/trainA\\201746.png']
# processing (201750)-th image... ['./datasets/face2sketch/trainA\\201751.png']
# processing (201755)-th image... ['./datasets/face2sketch/trainA\\201756.png']
# processing (201760)-th image... ['./datasets/face2sketch/trainA\\201761.png']
# processing (201765)-th image... ['./datasets/face2sketch/trainA\\201766.png']
# processing (201770)-th image... ['./datasets/face2sketch/trainA\\201771.png']
# processing (201775)-th image... ['./datasets/face2sketch/trainA\\201776.png']
# processing (201780)-th image... ['./datasets/face2sketch/trainA\\201781.png']
# processing (201785)-th image... ['./datasets/face2sketch/trainA\\201786.png']
# processing (201790)-th image... ['./datasets/face2sketch/trainA\\201791.png']
# processing (201795)-th image... ['./datasets/face2sketch/trainA\\201796.png']
# processing (201800)-th image... ['./datasets/face2sketch/trainA\\201801.png']
# processing (201805)-th image... ['./datasets/face2sketch/trainA\\201806.png']
# processing (201810)-th image... ['./datasets/face2sketch/trainA\\201811.png']
# processing (201815)-th image... ['./datasets/face2sketch/trainA\\201816.png']
# processing (201820)-th image... ['./datasets/face2sketch/trainA\\201821.png']
# processing (201825)-th image... ['./datasets/face2sketch/trainA\\201826.png']
# processing (201830)-th image... ['./datasets/face2sketch/trainA\\201831.png']
# processing (201835)-th image... ['./datasets/face2sketch/trainA\\201836.png']
# processing (201840)-th image... ['./datasets/face2sketch/trainA\\201841.png']
# processing (201845)-th image... ['./datasets/face2sketch/trainA\\201846.png']
# processing (201850)-th image... ['./datasets/face2sketch/trainA\\201851.png']
# processing (201855)-th image... ['./datasets/face2sketch/trainA\\201856.png']
# processing (201860)-th image... ['./datasets/face2sketch/trainA\\201861.png']
# processing (201865)-th image... ['./datasets/face2sketch/trainA\\201866.png']
# processing (201870)-th image... ['./datasets/face2sketch/trainA\\201871.png']
# processing (201875)-th image... ['./datasets/face2sketch/trainA\\201876.png']
# processing (201880)-th image... ['./datasets/face2sketch/trainA\\201881.png']
# processing (201885)-th image... ['./datasets/face2sketch/trainA\\201886.png']
# processing (201890)-th image... ['./datasets/face2sketch/trainA\\201891.png']
# processing (201895)-th image... ['./datasets/face2sketch/trainA\\201896.png']
# processing (201900)-th image... ['./datasets/face2sketch/trainA\\201901.png']
# processing (201905)-th image... ['./datasets/face2sketch/trainA\\201906.png']
# processing (201910)-th image... ['./datasets/face2sketch/trainA\\201911.png']
# processing (201915)-th image... ['./datasets/face2sketch/trainA\\201916.png']
# processing (201920)-th image... ['./datasets/face2sketch/trainA\\201921.png']
# processing (201925)-th image... ['./datasets/face2sketch/trainA\\201926.png']
# processing (201930)-th image... ['./datasets/face2sketch/trainA\\201931.png']
# processing (201935)-th image... ['./datasets/face2sketch/trainA\\201936.png']
# processing (201940)-th image... ['./datasets/face2sketch/trainA\\201941.png']
# processing (201945)-th image... ['./datasets/face2sketch/trainA\\201946.png']
# processing (201950)-th image... ['./datasets/face2sketch/trainA\\201951.png']
# processing (201955)-th image... ['./datasets/face2sketch/trainA\\201956.png']
# processing (201960)-th image... ['./datasets/face2sketch/trainA\\201961.png']
# processing (201965)-th image... ['./datasets/face2sketch/trainA\\201966.png']
# processing (201970)-th image... ['./datasets/face2sketch/trainA\\201971.png']
# processing (201975)-th image... ['./datasets/face2sketch/trainA\\201976.png']
# processing (201980)-th image... ['./datasets/face2sketch/trainA\\201981.png']
# processing (201985)-th image... ['./datasets/face2sketch/trainA\\201986.png']
# processing (201990)-th image... ['./datasets/face2sketch/trainA\\201991.png']
# processing (201995)-th image... ['./datasets/face2sketch/trainA\\201996.png']
# processing (202000)-th image... ['./datasets/face2sketch/trainA\\202001.png']
# processing (202005)-th image... ['./datasets/face2sketch/trainA\\202006.png']
# processing (202010)-th image... ['./datasets/face2sketch/trainA\\202011.png']
# processing (202015)-th image... ['./datasets/face2sketch/trainA\\202016.png']
# processing (202020)-th image... ['./datasets/face2sketch/trainA\\202021.png']
# processing (202025)-th image... ['./datasets/face2sketch/trainA\\202026.png']
# processing (202030)-th image... ['./datasets/face2sketch/trainA\\202031.png']
# processing (202035)-th image... ['./datasets/face2sketch/trainA\\202036.png']
# processing (202040)-th image... ['./datasets/face2sketch/trainA\\202041.png']
# processing (202045)-th image... ['./datasets/face2sketch/trainA\\202046.png']
# processing (202050)-th image... ['./datasets/face2sketch/trainA\\202051.png']
# processing (202055)-th image... ['./datasets/face2sketch/trainA\\202056.png']
# processing (202060)-th image... ['./datasets/face2sketch/trainA\\202061.png']
# processing (202065)-th image... ['./datasets/face2sketch/trainA\\202066.png']
# processing (202070)-th image... ['./datasets/face2sketch/trainA\\202071.png']
# processing (202075)-th image... ['./datasets/face2sketch/trainA\\202076.png']
# processing (202080)-th image... ['./datasets/face2sketch/trainA\\202081.png']
# processing (202085)-th image... ['./datasets/face2sketch/trainA\\202086.png']
# processing (202090)-th image... ['./datasets/face2sketch/trainA\\202091.png']
# processing (202095)-th image... ['./datasets/face2sketch/trainA\\202096.png']
# processing (202100)-th image... ['./datasets/face2sketch/trainA\\202101.png']
# processing (202105)-th image... ['./datasets/face2sketch/trainA\\202106.png']
# processing (202110)-th image... ['./datasets/face2sketch/trainA\\202111.png']
# processing (202115)-th image... ['./datasets/face2sketch/trainA\\202116.png']
# processing (202120)-th image... ['./datasets/face2sketch/trainA\\202121.png']
# processing (202125)-th image... ['./datasets/face2sketch/trainA\\202126.png']
# processing (202130)-th image... ['./datasets/face2sketch/trainA\\202131.png']
# processing (202135)-th image... ['./datasets/face2sketch/trainA\\202136.png']
# processing (202140)-th image... ['./datasets/face2sketch/trainA\\202141.png']
# processing (202145)-th image... ['./datasets/face2sketch/trainA\\202146.png']
# processing (202150)-th image... ['./datasets/face2sketch/trainA\\202151.png']
# processing (202155)-th image... ['./datasets/face2sketch/trainA\\202156.png']
# processing (202160)-th image... ['./datasets/face2sketch/trainA\\202161.png']
# processing (202165)-th image... ['./datasets/face2sketch/trainA\\202166.png']
# processing (202170)-th image... ['./datasets/face2sketch/trainA\\202171.png']
# processing (202175)-th image... ['./datasets/face2sketch/trainA\\202176.png']
# processing (202180)-th image... ['./datasets/face2sketch/trainA\\202181.png']
# processing (202185)-th image... ['./datasets/face2sketch/trainA\\202186.png']
# processing (202190)-th image... ['./datasets/face2sketch/trainA\\202191.png']
# processing (202195)-th image... ['./datasets/face2sketch/trainA\\202196.png']
# processing (202200)-th image... ['./datasets/face2sketch/trainA\\202201.png']
# processing (202205)-th image... ['./datasets/face2sketch/trainA\\202206.png']
# processing (202210)-th image... ['./datasets/face2sketch/trainA\\202211.png']
# processing (202215)-th image... ['./datasets/face2sketch/trainA\\202216.png']
# processing (202220)-th image... ['./datasets/face2sketch/trainA\\202221.png']
# processing (202225)-th image... ['./datasets/face2sketch/trainA\\202226.png']
# processing (202230)-th image... ['./datasets/face2sketch/trainA\\202231.png']
# processing (202235)-th image... ['./datasets/face2sketch/trainA\\202236.png']
# processing (202240)-th image... ['./datasets/face2sketch/trainA\\202241.png']
# processing (202245)-th image... ['./datasets/face2sketch/trainA\\202246.png']
# processing (202250)-th image... ['./datasets/face2sketch/trainA\\202251.png']
# processing (202255)-th image... ['./datasets/face2sketch/trainA\\202256.png']
# processing (202260)-th image... ['./datasets/face2sketch/trainA\\202261.png']
# processing (202265)-th image... ['./datasets/face2sketch/trainA\\202266.png']
# processing (202270)-th image... ['./datasets/face2sketch/trainA\\202271.png']
# processing (202275)-th image... ['./datasets/face2sketch/trainA\\202276.png']
# processing (202280)-th image... ['./datasets/face2sketch/trainA\\202281.png']
# processing (202285)-th image... ['./datasets/face2sketch/trainA\\202286.png']
# processing (202290)-th image... ['./datasets/face2sketch/trainA\\202291.png']
# processing (202295)-th image... ['./datasets/face2sketch/trainA\\202296.png']
# processing (202300)-th image... ['./datasets/face2sketch/trainA\\202301.png']
# processing (202305)-th image... ['./datasets/face2sketch/trainA\\202306.png']
# processing (202310)-th image... ['./datasets/face2sketch/trainA\\202311.png']
# processing (202315)-th image... ['./datasets/face2sketch/trainA\\202316.png']
# processing (202320)-th image... ['./datasets/face2sketch/trainA\\202321.png']
# processing (202325)-th image... ['./datasets/face2sketch/trainA\\202326.png']
# processing (202330)-th image... ['./datasets/face2sketch/trainA\\202331.png']
# processing (202335)-th image... ['./datasets/face2sketch/trainA\\202336.png']
# processing (202340)-th image... ['./datasets/face2sketch/trainA\\202341.png']
# processing (202345)-th image... ['./datasets/face2sketch/trainA\\202346.png']
# processing (202350)-th image... ['./datasets/face2sketch/trainA\\202351.png']
# processing (202355)-th image... ['./datasets/face2sketch/trainA\\202356.png']
# processing (202360)-th image... ['./datasets/face2sketch/trainA\\202361.png']
# processing (202365)-th image... ['./datasets/face2sketch/trainA\\202366.png']
# processing (202370)-th image... ['./datasets/face2sketch/trainA\\202371.png']
# processing (202375)-th image... ['./datasets/face2sketch/trainA\\202376.png']
# processing (202380)-th image... ['./datasets/face2sketch/trainA\\202381.png']
# processing (202385)-th image... ['./datasets/face2sketch/trainA\\202386.png']
# processing (202390)-th image... ['./datasets/face2sketch/trainA\\202391.png']
# processing (202395)-th image... ['./datasets/face2sketch/trainA\\202396.png']
# processing (202400)-th image... ['./datasets/face2sketch/trainA\\202401.png']
# processing (202405)-th image... ['./datasets/face2sketch/trainA\\202406.png']
# processing (202410)-th image... ['./datasets/face2sketch/trainA\\202411.png']
# processing (202415)-th image... ['./datasets/face2sketch/trainA\\202416.png']
# processing (202420)-th image... ['./datasets/face2sketch/trainA\\202421.png']
# processing (202425)-th image... ['./datasets/face2sketch/trainA\\202426.png']
# processing (202430)-th image... ['./datasets/face2sketch/trainA\\202431.png']
# processing (202435)-th image... ['./datasets/face2sketch/trainA\\202436.png']
# processing (202440)-th image... ['./datasets/face2sketch/trainA\\202441.png']
# processing (202445)-th image... ['./datasets/face2sketch/trainA\\202446.png']
# processing (202450)-th image... ['./datasets/face2sketch/trainA\\202451.png']
# processing (202455)-th image... ['./datasets/face2sketch/trainA\\202456.png']
# processing (202460)-th image... ['./datasets/face2sketch/trainA\\202461.png']
# processing (202465)-th image... ['./datasets/face2sketch/trainA\\202466.png']
# processing (202470)-th image... ['./datasets/face2sketch/trainA\\202471.png']
# processing (202475)-th image... ['./datasets/face2sketch/trainA\\202476.png']
# processing (202480)-th image... ['./datasets/face2sketch/trainA\\202481.png']
# processing (202485)-th image... ['./datasets/face2sketch/trainA\\202486.png']
# processing (202490)-th image... ['./datasets/face2sketch/trainA\\202491.png']
# processing (202495)-th image... ['./datasets/face2sketch/trainA\\202496.png']
# processing (202500)-th image... ['./datasets/face2sketch/trainA\\202501.png']
# processing (202505)-th image... ['./datasets/face2sketch/trainA\\202506.png']
# processing (202510)-th image... ['./datasets/face2sketch/trainA\\202511.png']
# processing (202515)-th image... ['./datasets/face2sketch/trainA\\202516.png']
# processing (202520)-th image... ['./datasets/face2sketch/trainA\\202521.png']
# processing (202525)-th image... ['./datasets/face2sketch/trainA\\202526.png']
# processing (202530)-th image... ['./datasets/face2sketch/trainA\\202531.png']
# processing (202535)-th image... ['./datasets/face2sketch/trainA\\202536.png']
# processing (202540)-th image... ['./datasets/face2sketch/trainA\\202541.png']
# processing (202545)-th image... ['./datasets/face2sketch/trainA\\202546.png']
# processing (202550)-th image... ['./datasets/face2sketch/trainA\\202551.png']
# processing (202555)-th image... ['./datasets/face2sketch/trainA\\202556.png']
# processing (202560)-th image... ['./datasets/face2sketch/trainA\\202561.png']
# processing (202565)-th image... ['./datasets/face2sketch/trainA\\202566.png']
# processing (202570)-th image... ['./datasets/face2sketch/trainA\\202571.png']
# processing (202575)-th image... ['./datasets/face2sketch/trainA\\202576.png']
# processing (202580)-th image... ['./datasets/face2sketch/trainA\\202581.png']
# processing (202585)-th image... ['./datasets/face2sketch/trainA\\202586.png']
# processing (202590)-th image... ['./datasets/face2sketch/trainA\\202591.png']
# processing (202595)-th image... ['./datasets/face2sketch/trainA\\202596.png']

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_fake.png') #Will crash. Put actual result image path here
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_real.png') #Will crash. Put actual result image path here
plt.imshow(img)
